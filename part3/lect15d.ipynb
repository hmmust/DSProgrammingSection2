# %%
import numpy as np
import pandas as pd
students = pd.read_csv('students.csv')
students['Year'].value_counts(dropna=False)
#students['Major'].value_counts().plot.bar()
#students['Major'].value_counts().plot.pie()
students['Major'].value_counts().plot.barh()
# Out:
# <Axes: ylabel='Major'>
