# %%
import pandas as pd
import numpy as np

# %%
data1 = [["Sara",20],["Leen",19],["Diala",19],["Osama",22]]
df1 = pd.DataFrame(data1,columns=["name","age"])
df1.age.value_counts().plot.bar()
# Out:
# <Axes: xlabel='age'>

# %% [markdown]
# This is the first jupyter Notebook for pandas
